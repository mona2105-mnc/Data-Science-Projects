# %% [markdown]
# <a href="https://colab.research.google.com/github/mona2105-mnc/Data-Science-Projects/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SVM FROM SCRATCH

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np

# %% [markdown]
# Support Vector Machine Classifier

# %%
class SVM_classifier():

  def __init__(self,learning_rate,no_of_iterations,lambda_parameter):
    self.learning_rate=learning_rate
    self.no_of_iterations=no_of_iterations
    self.lambda_parameter=lambda_parameter


  def fit(self,X,Y):
    self.m,self.n=X.shape
    self.w=np.zeros(self.n)
    self.b=0
    self.X=X
    self.Y=Y
    for i in range(self.no_of_iterations):
      self.update_weights()

  def update_weights(self):
    y_label=np.where(self.Y<=0,-1,1)
    for index,x_i in enumerate(self.X):
      condition=y_label[index]*(np.dot(x_i,self.w)-self.b)>=1
      if(condition==True):
        dw=2*self.lambda_parameter*self.w
        db=0
      else:
        dw=2*self.lambda_parameter*self.w-np.dot(x_i,y_label[index])
        db=y_label[index]
      self.w=self.w-self.learning_rate*dw
      self.b=self.b-self.learning_rate*db

  def predict(self,X):

    output=np.dot(X,self.w)-self.b
    predicted_labels=np.sign(output)
    y_hat=np.where(predicted_labels<=-1,0,1)
    return y_hat

# %% [markdown]
# Importing the Dependencies

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Preprocessing

# %%
cell_df=pd.read_csv('/content/breast-cancer-wisconsin.data')

# %%
cell_df.head()
# Out:
#    1000025  5   1  1.1  1.2  2 1.3  3  1.4  1.5  2.1
# 0  1002945  5   4    4    5  7  10  3    2    1    2
# 1  1015425  3   1    1    1  2   2  3    1    1    2
# 2  1016277  6   8    8    1  3   4  3    7    1    2
# 3  1017023  4   1    1    3  2   1  3    1    1    2
# 4  1017122  8  10   10    8  7  10  9    7    1    4

# %%
cell_df.rename(columns={'100025':'Sample number','5':'clump thickness','1':'cell size uniformity','1.1':'cell shape uniformity','1.2':'marginal adhesion','2':'Single Epithelial Cell Size',
                        '1.3':'Bare Nuclei','3':'Bland Chromatin','1.4':'Normal Nucleoli','1.5':'Mitoses','2.1':'class'},inplace=True)

# %%
cell_df.drop(columns={'1000025'},inplace=True)

# %%
cell_df
# Out:
#      clump thickness  cell size uniformity  cell shape uniformity  ...  Normal Nucleoli  Mitoses class
# 0                  5                     4                      4  ...                2        1     2
# 1                  3                     1                      1  ...                1        1     2
# 2                  6                     8                      8  ...                7        1     2
# 3                  4                     1                      1  ...                1        1     2
# 4                  8                    10                     10  ...                7        1     4
# ..               ...                   ...                    ...  ...              ...      ...   ...
# 693                3                     1                      1  ...                1        1     2
# 694                2                     1                      1  ...                1        1     2
# ...

# %%
cell_df['class'] = cell_df['class'].apply(lambda x: 0 if x == 2 else 1)

# %%
cell_df.drop(columns={'Bare Nuclei'},inplace=True)

# %%
cell_df.iloc[490,:]  # Use iloc for integer-location based indexing
# Out:
# clump thickness                5
# cell size uniformity           8
# cell shape uniformity          9
# marginal adhesion              4
# Single Epithelial Cell Size    3
# Bland Chromatin                7
# Normal Nucleoli                1
# Mitoses                        1
# class                          1
# Name: 490, dtype: int64

# %%
cell_df['class'].value_counts()
# Out:
# class
# 0    457
# 1    241
# Name: count, dtype: int64

# %% [markdown]
# 0-> Non-Cancerous
#
# 1->Cancerous

# %%
features=cell_df.drop(columns='class',axis=1)
target=cell_df['class']

# %% [markdown]
# Data Standardization

# %%
scaler= StandardScaler()

# %%
scaler.fit(features)
# Out:
# StandardScaler()

# %%
standardized_data=scaler.transform(features)

# %%
print(standardized_data)
# Out:
# [[ 0.20709025  0.28273919  0.26572479 ... -0.17979494 -0.28486086
#   -0.34418721]
#  [-0.50322422 -0.7007423  -0.74412585 ... -0.17979494 -0.61242739
#   -0.34418721]
#  [ 0.56224749  1.59404784  1.61219231 ... -0.17979494  1.35297178
#   -0.34418721]
#  ...
#  [ 0.20709025  2.24970216  2.28542607 ...  1.87080747  2.33567136
#    0.23892607]
#  [-0.14806699  1.59404784  0.93895855 ...  2.69104844  1.02540525
#   -0.34418721]
#  [-0.14806699  1.59404784  1.61219231 ...  2.69104844  0.37027219
#   -0.34418721]]

# %%
features=standardized_data
target=cell_df['class']

# %%
print(features)
print(target)
# Out:
# [[ 0.20709025  0.28273919  0.26572479 ... -0.17979494 -0.28486086
#   -0.34418721]
#  [-0.50322422 -0.7007423  -0.74412585 ... -0.17979494 -0.61242739
#   -0.34418721]
#  [ 0.56224749  1.59404784  1.61219231 ... -0.17979494  1.35297178
#   -0.34418721]
#  ...
#  [ 0.20709025  2.24970216  2.28542607 ...  1.87080747  2.33567136
#    0.23892607]
#  [-0.14806699  1.59404784  0.93895855 ...  2.69104844  1.02540525
#   -0.34418721]
#  [-0.14806699  1.59404784  1.61219231 ...  2.69104844  0.37027219
#   -0.34418721]]
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 693    0
# 694    0
# 695    1
# 696    1
# 697    1
# Name: class, Length: 698, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=2)

# %%
print(features.shape,X_train.shape,X_test.shape)
# Out:
# (698, 8) (558, 8) (140, 8)

# %% [markdown]
# Training the Model
#
# Support Vector Machine Classifier

# %%
classifier=SVM_classifier(learning_rate=0.001,no_of_iterations=1000,lambda_parameter=0.01)

# %%
classifier.fit(X_train,y_train)

# %% [markdown]
# Model Evaluation
#
# Accuracy Score

# %%
X_train_prediction=classifier.predict(X_train)
training_data_accuracy=accuracy_score(y_train,X_train_prediction)

# %%
print('Accuracy score on training data= ',training_data_accuracy)
# Out:
# Accuracy score on training data=  0.9659498207885304

# %%
X_test_prediction=classifier.predict(X_test)
test_data_accuracy=accuracy_score(y_test,X_test_prediction)

# %%
print('Accuracy score on test data= ',test_data_accuracy)
# Out:
# Accuracy score on test data=  0.9571428571428572

# %% [markdown]
# Building a Predictive System

# %%
input_data=(5,8,9,4,3,7,1,1)
input_data_as_numpy_array=np.asarray(input_data)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
std_data=scaler.transform(input_data_reshaped)
print(std_data)
prediction=classifier.predict(std_data)
print(prediction)

if (prediction[0]==0):
  print('The person has breast cancer')
else:
  print('The person does not have breast cancer')
# Out:
# [[ 0.20709025  1.59404784  1.94880919  0.41706773 -0.09836616  1.46068699
#   -0.61242739 -0.34418721]]
# [1]
# The person does not have breast cancer
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# THE END!
